# %% [markdown]
# # Model development and prediction

# %% [markdown]
# ## Initialize

# %% [markdown]
# ### Initialize directories

# %%
# Initialize main directory on the server
DIRECTORY = "/binf-isilon/alab/students/stefano/thesis_project/"                        # General directory

### Model and scaler

# Best performing model
FILENAME_MODEL = "pos_neg_shift_timepoint_0to2_all_merged_subtnorm"                     # Model filename (final pred)
MODEL_PATH = f"{DIRECTORY}Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/"     # Model path (save and load)

# %% [markdown]
# ### Import module

# %%
# Import 
import main_script_thesis_server

# %% [markdown]
# ### Load data (run or modify one of the following)

# %% [markdown]
# #### Train

# %%
## Train

# Path
IN_PATH = "Data/ML_input/timepoint_0to2_all_pos_neg_shift/subtnorm/"                                 # Path input data                          
IN_PATH_ML_RESULT = f"{DIRECTORY}Data/ML_output/predictions/timepoint_0to2_all_pos_neg_shift_new/"   # Load results to evaluate
OUT_PATH_ML_RESULT = f"{DIRECTORY}Data/ML_output/predictions/timepoint_0to2_all_pos_neg_shift_new/"  # Store results
OUT_PATH = f"{DIRECTORY}Plots/timepoint_0to2_all_pos_neg_shift_new/"                                 # Store plots, scaler and model                    
FILENAME = "pos_neg_shift_timepoint_0to2_all_merged_subtnorm"                                        # Data filenam

# Load data
X_TRAIN = pd.read_csv(f"{DIRECTORY}{IN_PATH}/profiles_{FILENAME}_train.csv").drop("label", axis = 1) 
metadata_train = pd.read_csv(f"{DIRECTORY}{IN_PATH}/metadata_{FILENAME}_train.csv")
y_TRAIN = metadata_train["label"]

print(X_TRAIN.shape)
print(y_TRAIN.shape)
# Out:
# (4363934, 301)
# (4363934,)

# %% [markdown]
# #### Train without FN < 0.15 & FP > 0.85 (experiment)

# %%
## Train without FN < 0.15 & FP > 0.85

# Path
IN_PATH = "Data/ML_input/timepoint_removed_wrongly_sure/timepoint_0to2_removed_wrongly_sure/"
IN_PATH_ML_RESULT = f"{DIRECTORY}Data/ML_output/predictions/timepoint_removed_wrongly_sure/"   
OUT_PATH_ML_RESULT = f"{DIRECTORY}Data/ML_output/predictions/timepoint_removed_wrongly_sure/"  
OUT_PATH = f"{DIRECTORY}Plots/timepoint_removed_wrongly_sure/"                                             
FILENAME = "timepoint_0to2_removed_wrongly_sure_lgbm_merged_subtnorm"

# Load data
X_TRAIN = pd.read_csv(f"{DIRECTORY}{IN_PATH}/profiles_{FILENAME}_train.csv").drop("label", axis = 1) 
metadata_train = pd.read_csv(f"{DIRECTORY}{IN_PATH}/metadata_{FILENAME}_train.csv")
y_TRAIN = metadata_train["label"]

print(X_TRAIN.shape)
print(y_TRAIN.shape)

# %% [markdown]
# #### Test

# %%
## Test

# Path
IN_PATH = "Data/ML_input/timepoint_6_pos_neg_shift/subtnorm/"
IN_PATH_ML_RESULT = f"{DIRECTORY}Data/ML_output/predictions/timepoint_easy_hard_samples/"   
OUT_PATH_ML_RESULT = f"{DIRECTORY}Data/ML_output/predictions/timepoint_easy_hard_samples/"  
OUT_PATH = f"{DIRECTORY}Plots/timepoint_easy_hard_samples/"                                             
FILENAME = "pos_neg_shift_timepoint_6_merged_subtnorm"

# Load data
X_TEST = pd.read_csv(f"{DIRECTORY}{IN_PATH}/profiles_{FILENAME}_test.csv").drop("label", axis = 1) 
metadata_test = pd.read_csv(f"{DIRECTORY}{IN_PATH}/metadata_{FILENAME}_test.csv")
y_TEST = metadata_test["label"]

print(X_TEST.shape)
print(y_TEST.shape)
# Out:
# (859469, 602)
# (859469,)

# %% [markdown]
# #### Test meuleman

# %%
## Test meuleman

# Path
IN_PATH = "Data/ML_input/timepoint_6_meuleman/subtnorm/"
IN_PATH_ML_RESULT = f"{DIRECTORY}Data/ML_output/predictions/hela/"   
OUT_PATH_ML_RESULT = f"{DIRECTORY}Data/ML_output/predictions/hela/"  
OUT_PATH = f"{DIRECTORY}Plots/timepoint_6_meuleman/"                                             
FILENAME = "meuleman_timepoint_6_merged_subtnorm"

# Load data
X_TEST = pd.read_csv(f"{DIRECTORY}{IN_PATH}/profiles_{FILENAME}_test.csv").drop("label", axis = 1) 
metadata_test = pd.read_csv(f"{DIRECTORY}{IN_PATH}/metadata_{FILENAME}_test.csv")
y_TEST = metadata_test["label"]

print(X_TEST.shape)
print(y_TEST.shape)

# %% [markdown]
# #### Test HeLa

# %%
## Test HeLa

# Path
IN_PATH = "Data/ML_input/hela/"                                                
IN_PATH_ML_RESULT = f"{DIRECTORY}Data/ML_output/predictions/hela/"             
OUT_PATH_ML_RESULT = f"{DIRECTORY}Data/ML_output/predictions/hela/"            
OUT_PATH = f"{DIRECTORY}Plots/hela/Both_experiments/"                          
FILENAME = "hela_Rrp40_merged_subtnorm"                                        
#FILENAME = "hela_Both_experiments_merged_subtnorm"                           
#FILENAME = "hela_EGFP_merged_subtnorm"                                        

# Load data
X_TEST = pd.read_csv(f"{DIRECTORY}{IN_PATH}/profiles_{FILENAME}_test.csv").drop("label", axis = 1) 
metadata_test = pd.read_csv(f"{DIRECTORY}{IN_PATH}/metadata_{FILENAME}_test.csv")
y_TEST = metadata_test["label"]

print(X_TEST.shape)
print(y_TEST.shape)

# %% [markdown]
# #### Test without FN < 0.15 & FP > 0.85 (experiment)

# %%
## Test without FN < 0.15 & FP > 0.85

# Path
IN_PATH = "Data/ML_input/timepoint_removed_wrongly_sure/timepoint_6_removed_wrongly_sure/"
IN_PATH_ML_RESULT = f"{DIRECTORY}Data/ML_output/predictions/timepoint_removed_wrongly_sure/"   
OUT_PATH_ML_RESULT = f"{DIRECTORY}Data/ML_output/predictions/timepoint_removed_wrongly_sure/"  
OUT_PATH = f"{DIRECTORY}Plots/timepoint_removed_wrongly_sure/"                                            
FILENAME = "timepoint_6_removed_wrongly_sure_lgbm_merged_subtnorm"

# Load data
X_TEST = pd.read_csv(f"{DIRECTORY}{IN_PATH}/profiles_{FILENAME}_test.csv").drop("label", axis = 1) 
metadata_test = pd.read_csv(f"{DIRECTORY}{IN_PATH}/metadata_{FILENAME}_test.csv")
y_TEST = metadata_test["label"]

print(X_TEST.shape)
print(y_TEST.shape)

# %% [markdown]
# #### Genome wide predictions

# %%
## Genome wide predictions

# Path
IN_PATH = "Data/ML_input/genome_wide_predictions/timepoint_0_A2_chr1/"
OUT_PATH_ML_RESULT = f"{DIRECTORY}Plots/genome_wide_pred_timepoint_0_A2_TEST/" 
OUT_PATH = f"{DIRECTORY}Plots/genome_wide_pred_timepoint_0_A2_TEST/" 
FILENAME = "genome_wide_pred_timepoint_0_A2_chr1_subtnorm"

# Load data
X_TEST = pd.read_csv(f"{DIRECTORY}{IN_PATH}/profiles_{FILENAME}.csv")
metadata_test = pd.read_csv(f"{DIRECTORY}{IN_PATH}/metadata_{FILENAME}.csv")

print(X_TEST.shape)

# %% [markdown]
# ## LightGBM

# %% [markdown]
# ### LGBM parameter tuning

# %% [markdown]
# #### BayesianOptimization tuning

# %%
## BayesianOptimization with parameters to prevent overfitting

params = {"application" : "binary",
          "metric" : "None",                      # Set to None to use only the custom metric
          "force_row_wise" : True,
          "learning_rate" : 0.009,
          "scale_pos_weight": 5,
          "verbose": -1,                          # Set to -1 to hide all LGBM messages
          'device': 'gpu',
          'gpu_platform_id': 0,
          'gpu_device_id': 0
         }

pbounds = {"learning_rate": (0.001, 0.1),         # Laurae: keep it only for training speed, not to tune (otherwise overfitting)
           #"scale_pos_weight": (1.0, 3.0),       # Info: weight of labels with positive class
           "num_leaves": (7, 2000),               # (int) Info: max number of leaves in one tree
           "max_depth": (3, 62),                  # (int) Info: limit the max depth of the trees
           "min_data_in_leaf": (1, 256),          # (int) Info: can prevent overfitting. Default: 20
           "min_data_in_bin": (1, 256),           # (int) Info: can prevent overfitting
           "min_gain_to_split": (0.1, 5),         # Info: can speed up the training
           "min_child_weight": (0.01, 90),        # Info: minimum sum of instance weight (hessian) needed in a child (leaf); can prevent overfitting. Laurae: [0.01, (sample size / 1000)] 
           "feature_fraction": (0.5, 1),          # Info: randomly select a subset of features on each iteration (tree); can speed up the training; can prevent overfitting                  -> I would probably not use this
           "bagging_fraction": (0.5, 1),          # Info: randomly select part of data without resampling; can speed up the training; can prevent overfitting                                
           "lambda_l1": (0, 5),                   # Info: regularization
           "lambda_l2": (0, 5),                   # Info: regularization
           #"max_bin":(200, 300),                 # (int) Laurae: keep it only for memory pressure, not to tune (otherwise overfitting)
}

bayesopt_res = lgb_bayes_opt(X_TRAIN, y_TRAIN, metadata_train, params, pbounds,
               opt_init_points=5, opt_iteratations=50,
               num_iterations=1500, early_stopping_rounds=None,                           # Set num_iterations = 5000 (or 99999) and early_stopping_rounds = 500 
               metrics="f1_score", opt_verbose=2, cv_verbose=0, final_cv_eval=True)
# Out:
# |   iter    |  target   | baggin... | featur... | lambda_l1 | lambda_l2 | learni... | max_depth | min_ch... | min_da... | min_da... | min_ga... | num_le... |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# >> LGBM CV final report
# Train accuracy: 0.7343
# Train F1-score: 0.6894
# Train MCC: 0.4152
# Val accuracy: 0.7225
# Val F1-score: 0.6759
# Val MCC: 0.3877
# Val TNR = 72.00%
# Val TPR = 72.00%
# Duration: 0:08:03.877593
# |  1        |  0.6759   |  0.7085   |  0.8602   |  0.000571 |  1.512    |  0.01553  |  8.448    |  16.77    |  89.12    |  102.2    |  2.74     |  842.5    |
#
# >> LGBM CV final report
# Train accuracy: 0.7178
# Train F1-score: 0.6756
# Train MCC: 0.3964
# Val accuracy: 0.7102
# Val F1-score: 0.6669
# Val MCC: 0.3781
# Val TNR = 70.00%
# Val TPR = 73.00%
# Duration: 0:07:02.526795
# ...

# %% [markdown]
# #### Sci-kit optimize tuning

# %%
## LGBM tuning Sci-kit optimize BayesSearchCV

model = lgb.LGBMClassifier(silent=False, n_jobs=-1, verbose=-1,  
                           n_estimators=1500, metric=['roc_auc'],
                           application="binary", force_row_wise=True,
                           device='gpu', gpu_platform_id=0, gpu_device_id=0,
                           scale_pos_weight=1.55)

param_grid ={"learning_rate": [0.001, 0.1], 'max_depth': [3, 62], 'num_leaves': [7, 2000]}

bayes_search_lgb_tuner = BayesSearchCV(model, param_grid, n_iter=1500,
                                       scoring = make_scorer(f1_score, average = "macro"),
                                       cv = search_cv_split(metadata_train, n_val_chr=3, max_cv_iter="auto", 
                                                            cv_seed=33, print_metrics=False),
                                       random_state = 33, verbose=10)

# To include in the analysis
def status_print(optim_result):
    """Print the result of Sci-kit learn BayesSearchCV."""
    print('Best score: {}'.format(bayes_search_lgb_tuner.best_score_))
    print('params = {}'.format(bayes_search_lgb_tuner.best_params_))

bayes_search_res = bayes_search_lgb_tuner.fit(X_TRAIN, y_TRAIN, callback=status_print)
bayes_search_res

# %% [markdown]
# #### HyperOpt tuning

# %%
## LGBM tuning HyperOpt

params = {"application" : "binary",
          "metric" : "None",                      # Set to None to use only the custom metric
          "force_row_wise" : True,
          #"learning_rate" : 0.009,
          "scale_pos_weight": 5,
          "verbose": -1,                          # Set to -1 to hide all LGBM messages
          'device': 'gpu',
          'gpu_platform_id': 0,
          'gpu_device_id': 0}

pbounds = {'learning_rate': hp.quniform('learning_rate', 0.1, 0.001, 0.001),
           'max_depth': hp.choice('max_depth', np.arange(3, 62, dtype=int)),
           'num_leaves': hp.choice('num_leaves', np.arange(7, 2000, dtype=int)),
           # 'boosting_type': hp.choice('boosting_type', ['gbdt', 'dart']),
           # 'colsample_bytree': hp.uniform('colsample_by_tree', 0.6, 1.0),
           # 'reg_lambda': hp.uniform('reg_lambda', 0.0, 1.0)
           }          

best_par_hyperopt, hyperopt_res = lgb_hyperopt(X_TRAIN, y_TRAIN, metadata_train, 
                                               fixed_params=params, pbounds=pbounds, opt_iteratations=20,
                                               num_iterations=1500, early_stopping_rounds=None,
                                               print_eval=True)

print(hyperopt_res)
print(best_par_hyperopt)
# Out:
# {'learning_rate': 0.033, 'max_depth': 31, 'num_leaves': 139}
# Duration: 0:19:34.440411 | F1-score: 0.6939174464893527 | TNR: 0.7683285714285714 | TPR: 0.6846285714285714
# {'learning_rate': 0.094, 'max_depth': 23, 'num_leaves': 742}
# Duration: 0:28:27.039757 | F1-score: 0.7016727895244717 | TNR: 0.8419000000000001 | TPR: 0.5725714285714286
# {'learning_rate': 0.067, 'max_depth': 48, 'num_leaves': 1765}
# Duration: 0:54:22.168446 | F1-score: 0.6965814657680615 | TNR: 0.8654142857142857 | TPR: 0.5214
# {'learning_rate': 0.099, 'max_depth': 20, 'num_leaves': 1929}
# Duration: 0:25:26.981330 | F1-score: 0.7012267620420537 | TNR: 0.8345857142857144 | TPR: 0.5840714285714286
# {'learning_rate': 0.059000000000000004, 'max_depth': 37, 'num_leaves': 1421}
# Duration: 0:44:10.973224 | F1-score: 0.7004008314907499 | TNR: 0.8489428571428572 | TPR: 0.5575000000000001
# {'learning_rate': 0.064, 'max_depth': 14, 'num_leaves': 284}
# ...

# %% [markdown]
# ### LGBM training

# %% [markdown]
# #### Tuned parameters to prevent overfitting

# %%
params = {"application" : "binary",
          "metric" : "cross_entropy",
          "force_row_wise" : True,
          "verbose" :-1,
#           'device': 'gpu',
#           'gpu_platform_id': 0,
#           'gpu_device_id': 0,   
          "learning_rate" : 0.02615,
          "num_leaves":  1615,
          "max_depth": 14, 
          "min_data_in_leaf": 2,
          "min_data_in_bin": 43,
          "min_gain_to_split": 1.853, 
          "min_child_weight": 3.1, 
          "feature_fraction": 0.71,             
          "bagging_fraction": 0.9638,                                 
          "lambda_l1": 0.0241,    
          "lambda_l2": 4.907,     
          #"max_bin":(200, 300)        
}

# %% [markdown]
# #### Final training data (timepoint 2to0 all merged neg_pos_shift subtnorm data)

# %%
# Training timepoint 0to2 

lgb_cv_train_output, lgb_cv_val_output, lgb_importance = lgb_cv(X_TRAIN, y_TRAIN, metadata_train, params, 
                                                                num_iterations=3000, cv_seed=33, 
                                                                metrics="loss", early_stopping_rounds=500,
                                                                verbose=50, name="LGBM_7folds",
                                                                class_weight="auto")

# Store prediction
lgb_cv_train_output.to_csv(f"{OUT_PATH_ML_RESULT}default/lgb_cv_train_output_{FILENAME}.csv", index=False)
lgb_cv_val_output.to_csv(f"{OUT_PATH_ML_RESULT}default/lgb_cv_val_output_{FILENAME}.csv", index=False) 
lgb_importance.to_csv(f"{OUT_PATH_ML_RESULT}default/lgb_importance_{FILENAME}.csv", index=False)
# Out:
# Performing LGBM_7folds CV
#
# Parameters:
#   num_iterations = 3000
#   early_stopping_rounds = 500
#   application = binary
#   metric = cross_entropy
#   force_row_wise = True
#   verbose = -1
#   learning_rate = 0.02615
#   num_leaves = 1615
#   max_depth = 14
#   min_data_in_leaf = 2
#   min_data_in_bin = 43
#   min_gain_to_split = 1.853
#   min_child_weight = 3.1
#   feature_fraction = 0.71
#   bagging_fraction = 0.9638
#   lambda_l1 = 0.0241
#   lambda_l2 = 4.907
#
# > Starting CV iteration 1, valid chrs = chr13, chr12, chr10
#
# Train examples:
#     Total: 3768081
#     Positive: 1775694 (47.12% of total)
#
# Val/Test examples:
#     Total: 595853
#     Positive: 289306 (48.55% of total)
#
# Positive weigth = 1.12
# Saving scaler:
# 	/binf-isilon/alab/students/stefano/thesis_project/Plots/final_plots/models/LGBM_7folds_cv_1_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# Train: (3768081, 301)
# Test: (595853, 301)
# ...

# %%
# Training timepoint 0to2 with training progression
# (it show the training progression across all CV but it slow down the training)

lgb_cv_train_output, lgb_cv_val_output, lgb_importance = lgb_cv(X_TRAIN, y_TRAIN, metadata_train, params, 
                                                                num_iterations=2800, cv_seed=33, 
                                                                metrics="all", early_stopping_rounds=None,
                                                                verbose=50, name="LGBM_7folds_showloss",
                                                                class_weight="auto", plt_save=True)
# Out:
# Performing LGBM_7folds_showloss CV
#
# Parameters:
#   num_iterations = 2800
#   early_stopping_rounds = None
#   application = binary
#   metric = cross_entropy
#   force_row_wise = True
#   verbose = -1
#   learning_rate = 0.02615
#   num_leaves = 1615
#   max_depth = 14
#   min_data_in_leaf = 2
#   min_data_in_bin = 43
#   min_gain_to_split = 1.853
#   min_child_weight = 3.1
#   feature_fraction = 0.71
#   bagging_fraction = 0.9638
#   lambda_l1 = 0.0241
#   lambda_l2 = 4.907
#
# > Starting CV iteration 1, valid chrs = chr13, chr12, chr10
#
# Train examples:
#     Total: 3768081
#     Positive: 1775694 (47.12% of total)
#
# Val/Test examples:
#     Total: 595853
#     Positive: 289306 (48.55% of total)
#
# Positive weight = 1.12
# Saving scaler:
# 	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm//LGBM_7folds_showloss_cv_1_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# ...

# %%
# Training timepoint 0to2 all (use concatenated strands to get feature importance)

lgb_cv_train_output, lgb_cv_val_output, lgb_importance = lgb_cv(X_TRAIN, y_TRAIN, metadata_train, params, 
                                                                num_iterations=3000, cv_seed=33, 
                                                                metrics="loss", early_stopping_rounds=500,
                                                                verbose=50, name="LGBM_7folds_TO_DELETE",
                                                                class_weight="auto")

# Store prediction
lgb_cv_train_output.to_csv(f"{OUT_PATH_ML_RESULT}default/lgb_cv_train_output_{FILENAME}.csv", index=False)
lgb_cv_val_output.to_csv(f"{OUT_PATH_ML_RESULT}default/lgb_cv_val_output_{FILENAME}.csv", index=False) 
lgb_importance.to_csv(f"/binf-isilon/alab/students/stefano/thesis_project/Data/ML_output/lgb_importance_{FILENAME}.csv", index=False)
# Out:
# Performing LGBM_7folds_TO_DELETE CV
#
# Parameters:
#   num_iterations = 3000
#   early_stopping_rounds = 500
#   application = binary
#   metric = cross_entropy
#   force_row_wise = True
#   verbose = -1
#   learning_rate = 0.02615
#   num_leaves = 1615
#   max_depth = 14
#   min_data_in_leaf = 2
#   min_data_in_bin = 43
#   min_gain_to_split = 1.853
#   min_child_weight = 3.1
#   feature_fraction = 0.71
#   bagging_fraction = 0.9638
#   lambda_l1 = 0.0241
#   lambda_l2 = 4.907
#
# > Starting CV iteration 1, valid chrs = chr13, chr12, chr10
#
# Train examples:
#     Total: 3768081
#     Positive: 1775694 (47.12% of total)
#
# Val/Test examples:
#     Total: 595853
#     Positive: 289306 (48.55% of total)
#
# Positive weight = 1.12
# Saving scaler:
# 	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged//LGBM_7folds_TO_DELETE_cv_1_scaler_pos_neg_shift_timepoint_0to2_all_merged.pkl
# ...

# %% [markdown]
# ## CNN

# %%
## CNN
CNN_SEED = 333
METRICS = [keras.metrics.BinaryAccuracy(name='accuracy'),
           keras.metrics.Precision(name='precision'),
           keras.metrics.Recall(name='recall'),
           keras.metrics.AUC(name='auc')]
name = "CNN_1D"

# Define the model
def cnn_model(name=name, lr=0.00003, len_win=301, n_features=1, summary=False, print_name=True):
    """
    Define a CNN model. To train a different CNN model, this function must 
    be overwritten (defining a different architecture ) before running the 
    CNN training function cnn_cv().

    Otional
    :name: string
    :lr: int or float, learning rate
    :len_win: int, length of the genomic profiles
    :n_features: int, 1 for 1D CNN or 2 of 2D CNN
    :summary: boolean
    :print_name: boolean
    """  
    
    if print_name:
        print("Model:", name)
    model = Sequential(name=name)

    model.add(Conv1D(filters=32, kernel_size=3, padding="same", activation="relu", 
                  input_shape=(len_win, n_features)))
    model.add(Conv1D(filters=32, kernel_size=3, padding="same", activation="relu"))
    model.add(Conv1D(filters=32, kernel_size=3, padding="same", activation="relu"))
    model.add(Conv1D(filters=32, kernel_size=3, padding="same", activation="relu"))
    model.add(Conv1D(filters=32, kernel_size=3, padding="same", activation="relu"))
    model.add(MaxPooling1D(pool_size=5))

    model.add(Conv1D(filters=64, kernel_size=3, padding="same", activation="relu"))
    model.add(Conv1D(filters=64, kernel_size=3, padding="same", activation="relu"))
    model.add(Conv1D(filters=64, kernel_size=3, padding="same", activation="relu"))
    model.add(Conv1D(filters=64, kernel_size=3, padding="same", activation="relu"))
    model.add(Conv1D(filters=64, kernel_size=3, padding="same", activation="relu"))
    model.add(MaxPooling1D(pool_size=5))

    model.add(Conv1D(filters=128, kernel_size=3, padding="same", activation="relu"))
    model.add(Conv1D(filters=128, kernel_size=3, padding="same", activation="relu"))
    model.add(Conv1D(filters=128, kernel_size=3, padding="same", activation="relu"))
    model.add(Conv1D(filters=128, kernel_size=3, padding="same", activation="relu"))
    model.add(Conv1D(filters=128, kernel_size=3, padding="same", activation="relu"))
    model.add(GlobalMaxPooling1D())

    model.add(Dense(16, activation='relu'))
    model.add(Dropout(0.5, seed=CNN_SEED))

    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=keras.optimizers.Adam(lr=lr), 
                loss='binary_crossentropy', metrics=METRICS)
    if summary:
        model.summary()
    return model

# %% [markdown]
# ### CNN Training

# %% [markdown]
# #### Timepoint 0to2 all merged neg_pos_shift subtnorm

# %%
## CNN training (final model)

# Early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    verbose=1,
    patience=10,
    mode='min',
    restore_best_weights=True)

# Training
cnn_cv_train_output, cnn_cv_val_output = cnn_cv(X_TRAIN, y_TRAIN, metadata_train, 
                                                class_weight="auto", epochs=200, batch_size=2048, 
                                                plot_eval=True, verbose=0, custom_callbacks=False,
                                                early_stopping=early_stopping, n_val_chr=3,
                                                name="CNN_7folds5", cv_seed=33,
                                                plt_figsize=(20,18), plt_top=0.93, plt_save=False) 

# Store prediction
cnn_cv_train_output.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds5_cv_train_output_{FILENAME}.csv", index=False)
cnn_cv_val_output.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds5_cv_val_output_{FILENAME}.csv", index=False)
# Out:
# Performing CNN_7folds5 CV
#
# > Starting CV iteration 1, valid chrs = chr13, chr12, chr10
# Model: "cnn1d"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d_420 (Conv1D)          (None, 301, 32)           128
# _________________________________________________________________
# conv1d_421 (Conv1D)          (None, 301, 32)           3104
# _________________________________________________________________
# conv1d_422 (Conv1D)          (None, 301, 32)           3104
# _________________________________________________________________
# conv1d_423 (Conv1D)          (None, 301, 32)           3104
# _________________________________________________________________
# conv1d_424 (Conv1D)          (None, 301, 32)           3104
# _________________________________________________________________
# max_pooling1d_56 (MaxPooling (None, 60, 32)            0
# ...

# %%
## CNN training showing real training progression (final model)
## (it show real training progression but it slow down the training)        

# Early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    verbose=1,
    patience=10,
    mode='min',
    restore_best_weights=True)

# Training
cnn_cv_train_output, cnn_cv_val_output = cnn_cv(X_TRAIN, y_TRAIN, metadata_train, 
                                                class_weight="auto", epochs=200, batch_size=2048, 
                                                plot_eval=True, verbose=0, custom_callbacks=True,
                                                early_stopping=early_stopping, n_val_chr=3,
                                                name="CNN_7folds8", cv_seed=33,
                                                plt_figsize=(20,18), plt_top=0.93, plt_save=True) 
  
# Store prediction
cnn_cv_train_output.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds8_cv_train_output_{FILENAME}.csv", index=False)
cnn_cv_val_output.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds8_cv_val_output_{FILENAME}.csv", index=False)
# Out:
# Performing CNN_7folds8 CV
#
# > Starting CV iteration 1, valid chrs = chr13, chr12, chr10
# Model: "cnn1d"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d_690 (Conv1D)          (None, 301, 32)           128
# _________________________________________________________________
# conv1d_691 (Conv1D)          (None, 301, 32)           3104
# _________________________________________________________________
# conv1d_692 (Conv1D)          (None, 301, 32)           3104
# _________________________________________________________________
# conv1d_693 (Conv1D)          (None, 301, 32)           3104
# _________________________________________________________________
# conv1d_694 (Conv1D)          (None, 301, 32)           3104
# _________________________________________________________________
# max_pooling1d_92 (MaxPooling (None, 60, 32)            0
# ...

# %% [markdown]
# ## Final prediction

# %% [markdown]
# ### Prediction on test data

# %%
# Predictions test
output_lgb = final_pred(X_TEST, y_TEST, metadata_test, algo="lgbm", 
                                        scaler_model_name="LGBM_7folds", plt_save=True)
output_cnn = final_pred(X_TEST, y_TEST, metadata_test, algo="cnn", 
                                        scaler_model_name="CNN_7folds", plt_save=True)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}default/lgbm_7folds_test_output_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_test_output_{FILENAME}.csv", index=False)
# Out:
# Performing prediction with LGBM_7folds model
# Algorithm = LGBM
# Test examples:
#     Total: 859469
#     Positive: 415394 (48.33% of total)
#
# > Starting pred iteration 1
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Plots/final_plots/models/LGBM_7folds_cv_1_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# Loading model:	/binf-isilon/alab/students/stefano/thesis_project/Plots/final_plots/models/LGBM_7folds_cv_1_model_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.txt
# Report:
# Test F1-score: 0.7341
# Test MCC: 0.4836
# Test TNR = 84.45%
# Test TPR = 62.60%
# Test Precision = 0.7902
# Test Recall = 0.626
#
# > Starting pred iteration 2
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Plots/final_plots/models/LGBM_7folds_cv_2_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# ...

# %%
# Predictions hard test
output_lgb = final_pred(X_TEST, y_TEST, metadata_test, algo="lgbm", filename=FILENAME_MODEL, 
                        scaler_model_name="LGBM_7folds", plt_save=True)
output_cnn = final_pred(X_TEST, y_TEST, metadata_test, algo="cnn", filename=FILENAME_MODEL, 
                        scaler_model_name="CNN_7folds", plt_save=True)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}default/lgbm_7folds_hard_test_output_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_hard_test_output_{FILENAME}.csv", index=False)
# Out:
# Performing prediction with LGBM_7folds model
# Algorithm = LGBM
# Test examples:
#     Total: 184182
#     Positive: 88247 (47.91% of total)
#
# > Starting pred iteration 1
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Plots/final_plots/models/LGBM_7folds_cv_1_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# Loading model:	/binf-isilon/alab/students/stefano/thesis_project/Plots/final_plots/models/LGBM_7folds_cv_1_model_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.txt
# Report:
# Test F1-score: 0.7413
# Test MCC: 0.4927
# Test TNR = 83.37%
# Test TPR = 64.90%
# Test Precision = 0.7822
# Test Recall = 0.649
#
# > Starting pred iteration 2
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Plots/final_plots/models/LGBM_7folds_cv_2_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# ...

# %% [markdown]
# ### Prediction on test data HeLa cell line (DNase extraction)

# %% [markdown]
# #### Rrp40

# %%
# Predictions test
output_lgb = final_pred(X_TEST, y_TEST, metadata_test, algo="lgbm", 
                                        scaler_model_name="LGBM_7folds", plt_save=True)
output_cnn = final_pred(X_TEST, y_TEST, metadata_test, algo="cnn", 
                                        scaler_model_name="CNN_7folds", plt_save=True)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}default/lgbm_7folds_test_output_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_test_output_{FILENAME}.csv", index=False)
# Out:
# Performing prediction with LGBM_7folds model
# Algorithm = LGBM
# Test examples:
#     Total: 301257
#     Positive: 141436 (46.95% of total)
#
# > Starting pred iteration 1
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# Loading model:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_model_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.txt
# Report:
# Test F1-score: 0.8137
# Test MCC: 0.6322
# Test TNR = 77.34%
# Test TPR = 85.93%
# Test Precision = 0.7704
# Test Recall = 0.8593
#
# > Starting pred iteration 2
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_2_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# ...

# %% [markdown]
# #### EGFP

# %%
# Predictions test
output_lgb = final_pred(X_TEST, y_TEST, metadata_test, algo="lgbm", 
                                        scaler_model_name="LGBM_7folds", plt_save=True)
output_cnn = final_pred(X_TEST, y_TEST, metadata_test, algo="cnn", 
                                        scaler_model_name="CNN_7folds", plt_save=True)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}default/lgbm_7folds_test_output_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_test_output_{FILENAME}.csv", index=False)
# Out:
# Performing prediction with LGBM_7folds model
# Algorithm = LGBM
# Test examples:
#     Total: 186015
#     Positive: 87332 (46.95% of total)
#
# > Starting pred iteration 1
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# Loading model:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_model_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.txt
# Report:
# Test F1-score: 0.7874
# Test MCC: 0.5762
# Test TNR = 77.25%
# Test TPR = 80.48%
# Test Precision = 0.7579
# Test Recall = 0.8048
#
# > Starting pred iteration 2
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_2_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# ...

# %% [markdown]
# #### Both experiments

# %%
# Predictions test
output_lgb = final_pred(X_TEST, y_TEST, metadata_test, algo="lgbm", 
                                        scaler_model_name="LGBM_7folds", plt_save=True)
output_cnn = final_pred(X_TEST, y_TEST, metadata_test, algo="cnn", 
                                        scaler_model_name="CNN_7folds", plt_save=True)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}default/lgbm_7folds_test_output_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_test_output_{FILENAME}.csv", index=False)
# Out:
# Performing prediction with LGBM_7folds model
# Algorithm = LGBM
# Test examples:
#     Total: 487272
#     Positive: 228768 (46.95% of total)
#
# > Starting pred iteration 1
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# Loading model:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_model_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.txt
# Report:
# Test F1-score: 0.8037
# Test MCC: 0.6106
# Test TNR = 77.30%
# Test TPR = 83.85%
# Test Precision = 0.7658
# Test Recall = 0.8385
#
# > Starting pred iteration 2
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_2_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# ...

# %% [markdown]
# ### Prediction on TP 6 Meuleman (DNase extraction)

# %%
# Predictions test
output_lgb = final_pred(X_TEST, y_TEST, metadata_test, algo="lgbm", 
                                        scaler_model_name="LGBM_7folds", plt_save=True)
output_cnn = final_pred(X_TEST, y_TEST, metadata_test, algo="cnn", 
                                        scaler_model_name="CNN_7folds", plt_save=True)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}default/lgbm_7folds_test_output_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_test_output_{FILENAME}.csv", index=False)

# Apply threshold-moving
output_lgb = apply_threshold_pred(output_lgb, 0.479)
output_cnn = apply_threshold_pred(output_cnn, 0.492)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}thresholded/lgbm_7folds_test_output_{FILENAME}_j_thresholded.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}thresholded/cnn_7folds_test_output_{FILENAME}_j_thresholded.csv", index=False)
# Out:
# Performing prediction with LGBM_7folds model
# Algorithm = LGBM
# Test examples:
#     Total: 84558
#     Positive: 39803 (47.07% of total)
#
# > Starting pred iteration 1
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# Loading model:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_model_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.txt
# Report:
# Test F1-score: 0.7977
# Test MCC: 0.5954
# Test TNR = 80.57%
# Test TPR = 78.99%
# Test Precision = 0.7834
# Test Recall = 0.7899
#
# > Starting pred iteration 2
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_2_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# ...

# %% [markdown]
# ### Genome wide prediction

# %% [markdown]
# #### Tp0 A2 chr1

# %%
# Genome wide pred timepoint_0_A2_chr1
output_lgb = final_pred(X_TEST, None, metadata_test, algo="lgbm", filename=FILENAME_MODEL, 
                        scaler_model_name="LGBM_7folds", plt_save=True)
print("\n")
output_cnn = final_pred(X_TEST, None, metadata_test, algo="cnn", filename=FILENAME_MODEL, 
                        scaler_model_name="CNN_7folds", plt_save=True)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}lgbm_7folds_output_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}cnn_7folds_output_{FILENAME}.csv", index=False)
# Out:
# None
# False
# Performing prediction with LGBM_7folds model
# Algorithm = LGBM
#
# > Starting pred iteration 1
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# Loading model:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_model_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.txt
#
# > Starting pred iteration 2
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_2_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# Loading model:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_2_model_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.txt
#
# > Starting pred iteration 3
# ...

# %% [markdown]
# #### HeLa Rrp40 R1 chr1

# %%
# Genome wide pred timepoint_0_A2_chr1
output_lgb = final_pred(X_TEST, None, metadata_test, algo="lgbm", filename=FILENAME_MODEL, 
                        scaler_model_name="LGBM_7folds", plt_save=True)
print("\n")
output_cnn = final_pred(X_TEST, None, metadata_test, algo="cnn", filename=FILENAME_MODEL, 
                        scaler_model_name="CNN_7folds", plt_save=True)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}lgbm_7folds_output_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}cnn_7folds_output_{FILENAME}.csv", index=False)

# %%
# Apply threshold-moving
output_lgb_thr = apply_threshold_pred(output_lgb, 0.479)
output_cnn_thr = apply_threshold_pred(output_cnn, 0.492)

# Store prediction
output_lgb_thr.to_csv(f"{OUT_PATH_ML_RESULT}lgbm_7folds_output_{FILENAME}_j_thresholded.csv", index=False)
output_cnn_thr.to_csv(f"{OUT_PATH_ML_RESULT}cnn_7folds_output_{FILENAME}_j_thresholded.csv", index=False)

# %% [markdown]
# ## Experiments (not shown in the report)

# %% [markdown]
# ### Train model on easy samples (0.3 < P > 0.7) only

# %% [markdown]
# #### Pred train data TPs 0to2

# %%
# Predictions train
output_lgb = final_pred(X_TRAIN, y_TRAIN, metadata_train, algo="lgbm", 
                                          scaler_model_name="LGBM_7folds", plt_save=True)
output_cnn = final_pred(X_TRAIN, y_TRAIN, metadata_train, algo="cnn", 
                                          scaler_model_name="CNN_7folds", plt_save=True)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}default/lgbm_7folds_train_output_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_train_output_{FILENAME}.csv", index=False)

# %% [markdown]
# #### Subset the train data into easy_train and hard_train samples

# %%
## Select easy and hard samples based on predicted probabilities

i_easy_cnn = output_cnn["yprob"].apply(lambda x: True if x < 0.3 or x > 0.7 else False)

xtrain_easy_cnn = X_TRAIN[i_easy_cnn]
metadata_easy_cnn = metadata_train[i_easy_cnn]
xtrain_hard_cnn = X_TRAIN[~i_easy_cnn]
metadata_hard_cnn = metadata_train[~i_easy_cnn]

# Store subtorm profiles 
xtrain_easy_cnn.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_easy_hard/timepoint_0to2_easy_hard/profiles_timepoint_0to2_easy_cnn_merged_subtnorm_train.csv", index=False)
metadata_easy_cnn.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_easy_hard/timepoint_0to2_easy_hard/metadata_timepoint_0to2_easy_cnn_merged_subtnorm_train.csv", index=False)
xtrain_hard_cnn.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_easy_hard/timepoint_0to2_easy_hard/profiles_timepoint_0to2_hard_cnn_merged_subtnorm_train.csv", index=False)
metadata_hard_cnn.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_easy_hard/timepoint_0to2_easy_hard/metadata_timepoint_0to2_hard_cnn_merged_subtnorm_train.csv", index=False)

# %%
## Do the same for merged profiles

xtrain_easy_cnn = X_TRAIN[i_easy_cnn]
metadata_easy_cnn = metadata_train[i_easy_cnn]
xtrain_hard_cnn = X_TRAIN[~i_easy_cnn]
metadata_hard_cnn = metadata_train[~i_easy_cnn]

# Store merged profiles
xtrain_easy_cnn.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_easy_hard/timepoint_0to2_easy_hard/profiles_timepoint_0to2_easy_cnn_merged_train.csv", index=False)
metadata_easy_cnn.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_easy_hard/timepoint_0to2_easy_hard/metadata_timepoint_0to2_easy_cnn_merged_train.csv", index=False)
xtrain_hard_cnn.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_easy_hard/timepoint_0to2_easy_hard/profiles_timepoint_0to2_hard_cnn_merged_train.csv", index=False)
metadata_hard_cnn.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_easy_hard/timepoint_0to2_easy_hard/metadata_timepoint_0to2_hard_cnn_merged_train.csv", index=False)

# %% [markdown]
# #### Pred test data TP 6

# %%
# Predictions TP6 standard model
output_lgb = final_pred(X_TEST_subt, y_TEST_subt, metadata_test_subt, algo="lgbm", 
                        scaler_model_name="LGBM_7folds", plt_save=True)
output_cnn = final_pred(X_TEST_subt, y_TEST_subt, metadata_test_subt, algo="cnn", 
                        scaler_model_name="CNN_7folds", plt_save=True)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}default/lgbm_7folds_test_output_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_test_output_{FILENAME}.csv", index=False)
# Out:
# Performing prediction with LGBM_7folds model
# Algorithm = LGBM
# Test examples:
#     Total: 184182
#     Positive: 88247 (47.91% of total)
#
# > Starting pred iteration 1
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# Loading model:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_model_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.txt
# Report:
# Test F1-score: 0.7413
# Test MCC: 0.4927
# Test TNR = 83.37%
# Test TPR = 64.90%
# Test Precision = 0.7822
# Test Recall = 0.649
#
# > Starting pred iteration 2
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_2_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# ...

# %% [markdown]
# #### Subset test TP 6 in easy and hard based on predicted probabilities

# %%
## Select easy and hard samples based on predicted probabilities (subtnorm profiles)

i_easy_cnn = output_cnn["yprob"].apply(lambda x: True if x < 0.3 or x > 0.7 else False)

xtest_easy_cnn = X_TEST_subt[i_easy_cnn]
metadata_easy_cnn = metadata_test_subt[i_easy_cnn]
xtest_hard_cnn = X_TEST_subt[~i_easy_cnn]
metadata_hard_cnn = metadata_test_subt[~i_easy_cnn]

# Store subtorm profiles 
xtest_easy_cnn.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_easy_hard/timepoint_6_easy_hard/profiles_timepoint_6_easy_cnn_merged_subtnorm_test.csv", index=False)
metadata_easy_cnn.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_easy_hard/timepoint_6_easy_hard/metadata_timepoint_6_easy_cnn_merged_subtnorm_test.csv", index=False)
xtest_hard_cnn.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_easy_hard/timepoint_6_easy_hard/profiles_timepoint_6_hard_cnn_merged_subtnorm_test.csv", index=False)
metadata_hard_cnn.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_easy_hard/timepoint_6_easy_hard/metadata_timepoint_6_hard_cnn_merged_subtnorm_test.csv", index=False)

print("Subtnorm")
print(xtest_easy_cnn.shape)
print(metadata_easy_cnn.shape)
print(xtest_hard_cnn.shape)
print(metadata_hard_cnn.shape)


## Do the same for merged profiles

xtest_easy_cnn = X_TEST[i_easy_cnn]
metadata_easy_cnn = metadata_test[i_easy_cnn]
xtest_hard_cnn = X_TEST_subt[~i_easy_cnn]
metadata_hard_cnn = metadata_test[~i_easy_cnn]

# Store subtorm profiles 
xtest_easy_cnn.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_easy_hard/timepoint_6_easy_hard/profiles_timepoint_6_easy_cnn_merged_test.csv", index=False)
metadata_easy_cnn.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_easy_hard/timepoint_6_easy_hard/metadata_timepoint_6_easy_cnn_merged_test.csv", index=False)
xtest_hard_cnn.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_easy_hard/timepoint_6_easy_hard/profiles_timepoint_6_hard_cnn_merged_test.csv", index=False)
metadata_hard_cnn.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_easy_hard/timepoint_6_easy_hard/metadata_timepoint_6_hard_cnn_merged_test.csv", index=False)

print("\nMerged")
print(xtest_easy_cnn.shape)
print(metadata_easy_cnn.shape)
print(xtest_hard_cnn.shape)
print(metadata_hard_cnn.shape)
# Out:
# Subtnorm
# (93480, 301)
# (93480, 4)
# (90702, 301)
# (90702, 4)
#
# Merged
# (93480, 602)
# (93480, 4)
# (90702, 301)
# (90702, 4)

# %% [markdown]
# #### Train the model on the easy training data (TP 0to2)

# %%
### Training LGBM with timepoint 0to2 easy

# LGBM tuned against overfitting with ES
params = {"application" : "binary",
          "metric" : "cross_entropy",
          "force_row_wise" : True,
          "verbose" :-1,
#           'device': 'gpu',
#           'gpu_platform_id': 0,
#           'gpu_device_id': 0,   
          "learning_rate" : 0.02615,
          "num_leaves":  1615,
          "max_depth": 14, 
          "min_data_in_leaf": 2,
          "min_data_in_bin": 43,
          "min_gain_to_split": 1.853, 
          "min_child_weight": 3.1, 
          "feature_fraction": 0.71,             
          "bagging_fraction": 0.9638,                                 
          "lambda_l1": 0.0241,    
          "lambda_l2": 4.907,     
          #"max_bin":(200, 300)        
}
lgb_cv_train_output, lgb_cv_val_output, lgb_importance = lgb_cv(X_TRAIN, y_TRAIN, metadata_train, params, 
                                                                num_iterations=3000, cv_seed=33, 
                                                                metrics="loss", early_stopping_rounds=500,
                                                                verbose=50, name="LGBM_7folds_easy_03",
                                                                class_weight="auto")

# Store prediction
lgb_cv_train_output.to_csv(f"{OUT_PATH_ML_RESULT}default/lgb_7folds_cv_train_output_{FILENAME}.csv", index=False)
lgb_cv_val_output.to_csv(f"{OUT_PATH_ML_RESULT}default/lgb_7folds_cv_val_output_{FILENAME}.csv", index=False) 
lgb_importance.to_csv(f"{OUT_PATH_ML_RESULT}default/lgb_7folds_importance_{FILENAME}.csv", index=False)
# Out:
# Performing LGBM_7folds_easy_03 CV
#
# Parameters:
#   num_iterations = 3000
#   early_stopping_rounds = 500
#   application = binary
#   metric = cross_entropy
#   force_row_wise = True
#   verbose = -1
#   learning_rate = 0.02615
#   num_leaves = 1615
#   max_depth = 14
#   min_data_in_leaf = 2
#   min_data_in_bin = 43
#   min_gain_to_split = 1.853
#   min_child_weight = 3.1
#   feature_fraction = 0.71
#   bagging_fraction = 0.9638
#   lambda_l1 = 0.0241
#   lambda_l2 = 4.907
#
# > Starting CV iteration 1, valid chrs = chr13, chr12, chr10
#
# Train examples:
#     Total: 2025221
#     Positive: 1012859 (50.01% of total)
#
# Val/Test examples:
#     Total: 317919
#     Positive: 161389 (50.76% of total)
#
# Positive weigth = 1.0
# Saving scaler:
# 	/binf-isilon/alab/students/stefano/thesis_project/Models/timepoint_0to2_easy_merged_subtnorm/models/LGBM_7folds_easy_03_cv_1_scaler_timepoint_0to2_easy_cnn_merged_subtnorm.pkl
# ...

# %%
### Training CNN with timepoint 0to2 easy

# Early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    verbose=1,
    patience=10,
    mode='min',
    restore_best_weights=True)

# Training
cnn_cv_train_output, cnn_cv_val_output, cnn_histories = cnn_cv(X_TRAIN, y_TRAIN, metadata_train, 
                                                               class_weight="auto", epochs=200, batch_size=2048, 
                                                               plot_eval=True, verbose=0, custom_callbacks=False,
                                                               early_stopping=early_stopping, n_val_chr=3,
                                                               name="CNN_7folds_easy_03", cv_seed=33,
                                                               plt_figsize=(20,18), plt_top=0.93, plt_save=False) 

# Store prediction
cnn_cv_train_output.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_cv_train_output_{FILENAME}.csv", index=False)
cnn_cv_val_output.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_cv_val_output_{FILENAME}.csv", index=False)
# Out:
# Performing CNN_7folds_easy_03 CV
#
# > Starting CV iteration 1, valid chrs = chr13, chr12, chr10
# Model: "cnn1d"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d_60 (Conv1D)           (None, 301, 32)           128
# _________________________________________________________________
# conv1d_61 (Conv1D)           (None, 301, 32)           3104
# _________________________________________________________________
# conv1d_62 (Conv1D)           (None, 301, 32)           3104
# _________________________________________________________________
# conv1d_63 (Conv1D)           (None, 301, 32)           3104
# _________________________________________________________________
# conv1d_64 (Conv1D)           (None, 301, 32)           3104
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 60, 32)            0
# ...

# %% [markdown]
# #### Pred TP6 easy and hard with new and old model

# %%
# Predictions all TP6 new model
output_lgb = final_pred(X_TEST, y_TEST, metadata_test, algo="lgbm", 
                        scaler_model_name="LGBM_7folds_easy_03", plt_save=True)
output_cnn = final_pred(X_TEST, y_TEST, metadata_test, algo="cnn", 
                        scaler_model_name="CNN_7folds_easy_03", plt_save=True)

# Apply threshold-moving
output_lgb = apply_threshold_pred(output_lgb, 0.479)
output_cnn = apply_threshold_pred(output_cnn, 0.492)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}default/lgbm_7folds_easy_03_test_output_thresholded_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_easy_03_test_output_thresholded_{FILENAME}.csv", index=False)
# Out:
# Performing prediction with LGBM_7folds_easy_03 model
# Algorithm = LGBM
# Test examples:
#     Total: 184182
#     Positive: 88247 (47.91% of total)
#
# > Starting pred iteration 1
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/timepoint_0to2_easy_merged_subtnorm/LGBM_7folds_easy_03_cv_1_scaler_timepoint_0to2_easy_cnn_merged_subtnorm.pkl
# Loading model:	/binf-isilon/alab/students/stefano/thesis_project/Models/timepoint_0to2_easy_merged_subtnorm/LGBM_7folds_easy_03_cv_1_model_timepoint_0to2_easy_cnn_merged_subtnorm.txt
# Report:
# Test F1-score: 0.7363
# Test MCC: 0.4863
# Test TNR = 84.24%
# Test TPR = 63.11%
# Test Precision = 0.7865
# Test Recall = 0.6311
#
# > Starting pred iteration 2
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/timepoint_0to2_easy_merged_subtnorm/LGBM_7folds_easy_03_cv_2_scaler_timepoint_0to2_easy_cnn_merged_subtnorm.pkl
# ...

# %%
# Predictions TP6 hard using model trained on all samples

# Predictions all TP6
output_lgb = final_pred(X_TEST, y_TEST, metadata_test, algo="lgbm", 
                        scaler_model_name="LGBM_7folds", plt_save=True)
output_cnn = final_pred(X_TEST, y_TEST, metadata_test, algo="cnn", 
                        scaler_model_name="CNN_7folds", plt_save=True)

# Apply threshold-moving
output_lgb = apply_threshold_pred(output_lgb, 0.479)
output_cnn = apply_threshold_pred(output_cnn, 0.492)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}default/lgbm_7folds_test_output_thresholded_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_test_output_thresholded_{FILENAME}.csv", index=False)
# Out:
# Performing prediction with LGBM_7folds model
# Algorithm = LGBM
# Test examples:
#     Total: 90702
#     Positive: 42206 (46.53% of total)
#
# > Starting pred iteration 1
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# Loading model:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_model_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.txt
# Report:
# Test F1-score: 0.6165
# Test MCC: 0.256
# Test TNR = 77.88%
# Test TPR = 46.33%
# Test Precision = 0.6457
# Test Recall = 0.4633
#
# > Starting pred iteration 2
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_2_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# ...

# %%
# Predictions TP6 hard using model trained on easy samples only

# Predictions all TP6
output_lgb = final_pred(X_TEST, y_TEST, metadata_test, algo="lgbm", 
                        scaler_model_name="LGBM_7folds_easy_03", plt_save=True)
output_cnn = final_pred(X_TEST, y_TEST, metadata_test, algo="cnn", 
                        scaler_model_name="CNN_7folds_easy_03", plt_save=True)

# Apply threshold-moving
output_lgb = apply_threshold_pred(output_lgb, 0.479)
output_cnn = apply_threshold_pred(output_cnn, 0.492)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}default/lgbm_7folds_easy_03_test_output_thresholded_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_easy_03_test_output_thresholded_{FILENAME}.csv", index=False)
# Out:
# Performing prediction with LGBM_7folds_easy_03 model
# Algorithm = LGBM
# Test examples:
#     Total: 90702
#     Positive: 42206 (46.53% of total)
#
# > Starting pred iteration 1
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/timepoint_0to2_easy_merged_subtnorm/LGBM_7folds_easy_03_cv_1_scaler_timepoint_0to2_easy_cnn_merged_subtnorm.pkl
# Loading model:	/binf-isilon/alab/students/stefano/thesis_project/Models/timepoint_0to2_easy_merged_subtnorm/LGBM_7folds_easy_03_cv_1_model_timepoint_0to2_easy_cnn_merged_subtnorm.txt
# Report:
# Test F1-score: 0.6033
# Test MCC: 0.24
# Test TNR = 79.62%
# Test TPR = 42.57%
# Test Precision = 0.6451
# Test Recall = 0.4257
#
# > Starting pred iteration 2
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/timepoint_0to2_easy_merged_subtnorm/LGBM_7folds_easy_03_cv_2_scaler_timepoint_0to2_easy_cnn_merged_subtnorm.pkl
# ...

# %%
# Predictions TP6 easy using model trained on all samples

FILENAME_MODEL = "pos_neg_shift_timepoint_0to2_all_merged_subtnorm"                    # Model filename (final pred)
MODEL_PATH = f"{DIRECTORY}Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/" 

# Predictions all TP6
output_lgb = final_pred(X_TEST, y_TEST, metadata_test, algo="lgbm", 
                        scaler_model_name="LGBM_7folds", plt_save=True)
output_cnn = final_pred(X_TEST, y_TEST, metadata_test, algo="cnn", 
                        scaler_model_name="CNN_7folds", plt_save=True)

# Apply threshold-moving
output_lgb = apply_threshold_pred(output_lgb, 0.479)
output_cnn = apply_threshold_pred(output_cnn, 0.492)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}default/lgbm_7folds_test_output_thresholded_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_test_output_thresholded_{FILENAME}.csv", index=False)
# Out:
# Performing prediction with LGBM_7folds model
# Algorithm = LGBM
# Test examples:
#     Total: 93480
#     Positive: 46041 (49.25% of total)
#
# > Starting pred iteration 1
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# Loading model:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_model_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.txt
# Report:
# Test F1-score: 0.8548
# Test MCC: 0.7114
# Test TNR = 88.99%
# Test TPR = 81.92%
# Test Precision = 0.8784
# Test Recall = 0.8192
#
# > Starting pred iteration 2
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_2_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# ...

# %%
# Predictions TP6 easy using model trained on easy samples only

MODEL_PATH = f"{DIRECTORY}Models/timepoint_0to2_easy_merged_subtnorm/"             # Model path (save and load)
FILENAME_MODEL = "timepoint_0to2_easy_cnn_merged_subtnorm"      

# Predictions all TP6
output_lgb = final_pred(X_TEST, y_TEST, metadata_test, algo="lgbm", 
                        scaler_model_name="LGBM_7folds_easy_03", plt_save=True)
output_cnn = final_pred(X_TEST, y_TEST, metadata_test, algo="cnn", 
                        scaler_model_name="CNN_7folds_easy_03", plt_save=True)

# Apply threshold-moving
output_lgb = apply_threshold_pred(output_lgb, 0.479)
output_cnn = apply_threshold_pred(output_cnn, 0.492)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}default/lgbm_7folds_easy_03_test_output_thresholded_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_easy_03_test_output_thresholded_{FILENAME}.csv", index=False)
# Out:
# Performing prediction with LGBM_7folds_easy_03 model
# Algorithm = LGBM
# Test examples:
#     Total: 93480
#     Positive: 46041 (49.25% of total)
#
# > Starting pred iteration 1
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/timepoint_0to2_easy_merged_subtnorm/LGBM_7folds_easy_03_cv_1_scaler_timepoint_0to2_easy_cnn_merged_subtnorm.pkl
# Loading model:	/binf-isilon/alab/students/stefano/thesis_project/Models/timepoint_0to2_easy_merged_subtnorm/LGBM_7folds_easy_03_cv_1_model_timepoint_0to2_easy_cnn_merged_subtnorm.txt
# Report:
# Test F1-score: 0.8547
# Test MCC: 0.7113
# Test TNR = 88.97%
# Test TPR = 81.93%
# Test Precision = 0.8782
# Test Recall = 0.8193
#
# > Starting pred iteration 2
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/timepoint_0to2_easy_merged_subtnorm/LGBM_7folds_easy_03_cv_2_scaler_timepoint_0to2_easy_cnn_merged_subtnorm.pkl
# ...

# %% [markdown]
# ### Train model on samples without FP P > 0.7 & FN P < 0.3

# %% [markdown]
# #### Load pred train data TPs 0to2

# %%
output_lgb = pd.read_csv(f"{OUT_PATH_ML_RESULT}default/lgbm_7folds_train_output_{FILENAME}.csv")
output_cnn = pd.read_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_train_output_{FILENAME}.csv")

# %% [markdown]
# #### Subset the train data removing the wrongly classified profiles with large P

# %%
# Add confusion matrix info
output_lgb = add_confusion_cols(output_lgb)
output_cnn = add_confusion_cols(output_cnn)

# %%
## CNN

# All wrongly sure about
wrongly_sure = [((output_cnn["yprob"] > 0.7) & (output_cnn["confusion"] == "FP")) | ((output_cnn["yprob"] < 0.3) & (output_cnn["confusion"] == "FN"))]
n_wrong_sure = np.sum(wrongly_sure)
n_wrong = np.sum(output_cnn["prediction"] == "Wrong")
ratio_wrong_sure_all_wrong = round(n_wrong_sure / n_wrong * 100, 2)
print(f"Wrong samples that the model is sure about = {n_wrong_sure} on {n_wrong} wrong samples ({ratio_wrong_sure_all_wrong}%)")

# FP sure about
fp_sure = [(output_cnn["yprob"] > 0.7) & (output_cnn["confusion"] == "FP")]
n_fp_sure = np.sum(fp_sure)
n_fp = np.sum(output_cnn["confusion"] == "FP")
ratio_fp_sure_all_fp = round(n_fp_sure / n_fp * 100, 2)
print(f"FP samples that the model is sure about = {n_fp_sure} on {n_fp} FP samples ({ratio_fp_sure_all_fp}%)")

# FN sure about
fn_sure = [(output_cnn["yprob"] < 3) & (output_cnn["confusion"] == "FN")]
n_fn_sure = np.sum(fn_sure)
n_fn = np.sum(output_cnn["confusion"] == "FN")
ratio_fn_sure_all_fn = round(n_fn_sure / n_fn * 100, 2)
print(f"FN samples that the model is sure about = {n_fn_sure} on {n_fn} FN samples ({ratio_fn_sure_all_fn}%)")
# Out:
# Wrong samples that the model is sure about = 333409 on 1098627 wrong samples (30.35%)
# FP samples that the model is sure about = 125534 on 401799 FP samples (31.24%)
# FN samples that the model is sure about = 696828 on 696828 FN samples (100.0%)

# %%
## LGBM

# All wrongly sure about
wrongly_sure = [((output_lgb["yprob"] > 0.7) & (output_lgb["confusion"] == "FP")) | ((output_lgb["yprob"] < 0.3) & (output_lgb["confusion"] == "FN"))]
n_wrong_sure = np.sum(wrongly_sure)
n_wrong = np.sum(output_cnn["prediction"] == "Wrong")
ratio_wrong_sure_all_wrong = round(n_wrong_sure / n_wrong * 100, 2)
print(f"Wrong samples that the model is sure about = {n_wrong_sure} on {n_wrong} wrong samples ({ratio_wrong_sure_all_wrong}%)")

# FP sure about
fp_sure = [(output_lgb["yprob"] > 0.7) & (output_lgb["confusion"] == "FP")]
n_fp_sure = np.sum(fp_sure)
n_fp = np.sum(output_cnn["confusion"] == "FP")
ratio_fp_sure_all_fp = round(n_fp_sure / n_fp * 100, 2)
print(f"FP samples that the model is sure about = {n_fp_sure} on {n_fp} FP samples ({ratio_fp_sure_all_fp}%)")

# FN sure about
fn_sure = [(output_lgb["yprob"] < 0.3) & (output_lgb["confusion"] == "FN")]
n_fn_sure = np.sum(fn_sure)
n_fn = np.sum(output_cnn["confusion"] == "FN")
ratio_fn_sure_all_fn = round(n_fn_sure / n_fn * 100, 2)
print(f"FN samples that the model is sure about = {n_fn_sure} on {n_fn} FN samples ({ratio_fn_sure_all_fn}%)")
# Out:
# Wrong samples that the model is sure about = 284349 on 1098627 wrong samples (25.88%)
# FP samples that the model is sure about = 100823 on 401799 FP samples (25.09%)
# FN samples that the model is sure about = 183526 on 696828 FN samples (26.34%)

# %%
## Remove the training samples that the models wrongly classified with large probability by LGBM

xtrain_removed_wrong_sure_lgbm = X_TRAIN[~wrongly_sure[0]]
metadata_removed_wrong_sure_lgbm = metadata_train[~wrongly_sure[0]]

# Store subtorm profiles 
xtrain_removed_wrong_sure_lgbm.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_removed_wrongly_sure/timepoint_0to2_removed_wrongly_sure/profiles_timepoint_0to2_removed_wrongly_sure_lgbm_merged_subtnorm_train.csv", index=False)
metadata_removed_wrong_sure_lgbm.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_removed_wrongly_sure/timepoint_0to2_removed_wrongly_sure/metadata_timepoint_0to2_removed_wrongly_sure_lgbm_merged_subtnorm_train.csv", index=False)

# %%
# Store merged profiles 

xtrain_removed_wrong_sure_cnn = X_TRAIN[~wrongly_sure[0]]
metadata_removed_wrong_sure_cnn = metadata_train[~wrongly_sure[0]]

xtrain_removed_wrong_sure_lgbm.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_removed_wrongly_sure/timepoint_0to2_removed_wrongly_sure/profiles_timepoint_0to2_removed_wrongly_sure_lgbm_merged_train.csv", index=False)
metadata_removed_wrong_sure_lgbm.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_removed_wrongly_sure/timepoint_0to2_removed_wrongly_sure/metadata_timepoint_0to2_removed_wrongly_sure_lgbm_merged_train.csv", index=False)

# %% [markdown]
# #### Train the model on the training data removed the wrongly classified samples with large probability (TP 0to2)

# %%
### Training LGBM with timepoint 0to2 removed_wrongly_sure

# LGBM tuned against overfitting with ES
params = {"application" : "binary",
          "metric" : "cross_entropy",
          "force_row_wise" : True,
          "verbose" :-1,
#           'device': 'gpu',
#           'gpu_platform_id': 0,
#           'gpu_device_id': 0,   
          "learning_rate" : 0.02615,
          "num_leaves":  1615,
          "max_depth": 14, 
          "min_data_in_leaf": 2,
          "min_data_in_bin": 43,
          "min_gain_to_split": 1.853, 
          "min_child_weight": 3.1, 
          "feature_fraction": 0.71,             
          "bagging_fraction": 0.9638,                                 
          "lambda_l1": 0.0241,    
          "lambda_l2": 4.907,     
          #"max_bin":(200, 300)        
}
lgb_cv_train_output, lgb_cv_val_output, lgb_importance = lgb_cv(X_TRAIN, y_TRAIN, metadata_train, params, 
                                                                num_iterations=3000, cv_seed=33, 
                                                                metrics="loss", early_stopping_rounds=500,
                                                                verbose=50, name="LGBM_7folds",
                                                                class_weight="auto")

# Store prediction
lgb_cv_train_output.to_csv(f"{OUT_PATH_ML_RESULT}default/lgb_7folds_cv_train_output_{FILENAME}.csv", index=False)
lgb_cv_val_output.to_csv(f"{OUT_PATH_ML_RESULT}default/lgb_7folds_cv_val_output_{FILENAME}.csv", index=False) 
lgb_importance.to_csv(f"{OUT_PATH_ML_RESULT}default/lgb_7folds_importance_{FILENAME}.csv", index=False)
# Out:
# Performing LGBM_7folds CV
#
# Parameters:
#   num_iterations = 3000
#   early_stopping_rounds = 500
#   application = binary
#   metric = cross_entropy
#   force_row_wise = True
#   verbose = -1
#   learning_rate = 0.02615
#   num_leaves = 1615
#   max_depth = 14
#   min_data_in_leaf = 2
#   min_data_in_bin = 43
#   min_gain_to_split = 1.853
#   min_child_weight = 3.1
#   feature_fraction = 0.71
#   bagging_fraction = 0.9638
#   lambda_l1 = 0.0241
#   lambda_l2 = 4.907
#
# > Starting CV iteration 1, valid chrs = chr13, chr12, chr10
#
# Train examples:
#     Total: 3521265
#     Positive: 1617634 (45.94% of total)
#
# Val/Test examples:
#     Total: 558320
#     Positive: 263840 (47.26% of total)
#
# Positive weigth = 1.18
# Saving scaler:
# 	/binf-isilon/alab/students/stefano/thesis_project/Models/timepoint_0to2_removed_wrongly_sure_merged_subtnorm/models//LGBM_7folds_cv_1_scaler_timepoint_0to2_removed_wrongly_sure_lgbm_merged_subtnorm.pkl
# ...

# %%
### Training CNN with timepoint 0to2 removed_wrongly_sure

# Early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    verbose=1,
    patience=10,
    mode='min',
    restore_best_weights=True)

# Training
cnn_cv_train_output, cnn_cv_val_output, cnn_histories = cnn_cv(X_TRAIN, y_TRAIN, metadata_train, 
                                                               class_weight="auto", epochs=200, batch_size=2048, 
                                                               plot_eval=True, verbose=0, custom_callbacks=False,
                                                               early_stopping=early_stopping, n_val_chr=3,
                                                               name="CNN_7folds", cv_seed=33,
                                                               plt_figsize=(20,18), plt_top=0.93, plt_save=False) 

# Store prediction
cnn_cv_train_output.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_cv_train_output_{FILENAME}.csv", index=False)
cnn_cv_val_output.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_cv_val_output_{FILENAME}.csv", index=False)
# Out:
# Performing CNN_7folds CV
#
# > Starting CV iteration 1, valid chrs = chr13, chr12, chr10
# Model: "cnn1d"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d_75 (Conv1D)           (None, 301, 32)           128
# _________________________________________________________________
# conv1d_76 (Conv1D)           (None, 301, 32)           3104
# _________________________________________________________________
# conv1d_77 (Conv1D)           (None, 301, 32)           3104
# _________________________________________________________________
# conv1d_78 (Conv1D)           (None, 301, 32)           3104
# _________________________________________________________________
# conv1d_79 (Conv1D)           (None, 301, 32)           3104
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 60, 32)            0
# ...

# %% [markdown]
# #### Subset the hard test (TP6) removing the wrongly classified profiles with large P
#
# Load TP6 test merged and subtnorm

# %%
# Load pred on TP6 (from model trained on full training data)

output_lgb = pd.read_csv(f"{DIRECTORY}Data/ML_output/predictions/timepoint_easy_hard_samples/default/lgbm_7folds_test_output_pos_neg_shift_timepoint_6_merged_subtnorm.csv")
output_cnn = pd.read_csv(f"{DIRECTORY}Data/ML_output/predictions/timepoint_easy_hard_samples/default/cnn_7folds_test_output_pos_neg_shift_timepoint_6_merged_subtnorm.csv")

# Add confusion matrix info
output_lgb = add_confusion_cols(output_lgb)
output_cnn = add_confusion_cols(output_cnn)


## Remove the samples that the models wrongly classified with large probability by LGBM

wrongly_sure = [((output_lgb["yprob"] > 0.7) & (output_lgb["confusion"] == "FP")) | ((output_lgb["yprob"] < 0.3) & (output_lgb["confusion"] == "FN"))]
n_wrong_sure = np.sum(wrongly_sure)
n_wrong = np.sum(output_lgb["prediction"] == "Wrong")
ratio_wrong_sure_all_wrong = round(n_wrong_sure / n_wrong * 100, 2)
print(f"Wrong samples that the model is sure about = {n_wrong_sure} on {n_wrong} wrong samples ({ratio_wrong_sure_all_wrong}%)")

xtest_removed_wrong_sure_lgbm = X_TEST_subt[~wrongly_sure[0]]
metadata_removed_wrong_sure_lgbm = metadata_test_subt[~wrongly_sure[0]]

# Store subtorm profiles                     
xtest_removed_wrong_sure_lgbm.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_removed_wrongly_sure/timepoint_6_removed_wrongly_sure/profiles_timepoint_6_removed_wrongly_sure_lgbm_merged_subtnorm_test.csv", index=False)
metadata_removed_wrong_sure_lgbm.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_removed_wrongly_sure/timepoint_6_removed_wrongly_sure/metadata_timepoint_6_removed_wrongly_sure_lgbm_merged_subtnorm_test.csv", index=False)

print("Subtnorm")
print(xtest_removed_wrong_sure_lgbm.shape)
print(metadata_removed_wrong_sure_lgbm.shape)


## Do the same for merged profiles

xtest_removed_wrong_sure_lgbm = X_TEST[~wrongly_sure[0]]
metadata_removed_wrong_sure_lgbm = metadata_test[~wrongly_sure[0]]

# Store subtorm profiles 
xtest_removed_wrong_sure_lgbm.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_removed_wrongly_sure/timepoint_6_removed_wrongly_sure/profiles_timepoint_6_removed_wrongly_sure_lgbm_merged_test.csv", index=False)
metadata_removed_wrong_sure_lgbm.to_csv(f"{DIRECTORY}Data/ML_input/timepoint_removed_wrongly_sure/timepoint_6_removed_wrongly_sure/metadata_timepoint_6_removed_wrongly_sure_lgbm_merged_test.csv", index=False)

print("\nMerged")
print(xtest_removed_wrong_sure_lgbm.shape)
print(metadata_removed_wrong_sure_lgbm.shape)
# Out:
# Wrong samples that the model is sure about = 13546 on 46809 wrong samples (28.94%)
# Subtnorm
# (170636, 301)
# (170636, 4)
#
# Merged
# (170636, 602)
# (170636, 4)

# %%
# Store TP6 output with added confusion info

output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}default/confusion/lgbm_7folds_test_output_confusion_pos_neg_shift_merged_subtnorm.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}default/confusion/cnn_7folds_test_output_confusion_pos_neg_shift_merged_subtnorm.csv", index=False)

output_lgb_thr = apply_threshold_pred(output_lgb, 0.479)
output_cnn_thr = apply_threshold_pred(output_cnn, 0.479)

output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}thresholded/confusion/lgbm_7folds_test_output_confusion_timepoint_6_pos_neg_shift_merged_subtnorm_j_thresholded.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}thresholded/confusion/cnn_7folds_test_output_confusion_timepoint_6_pos_neg_shift_merged_subtnorm_j_thresholded.csv", index=False)

# %% [markdown]
# #### Pred TP6 removed wrongly_sure with new and old model

# %%
# Predictions all TP6 new model
output_lgb = final_pred(X_TEST, y_TEST, metadata_test, algo="lgbm", 
                        scaler_model_name="LGBM_7folds", plt_save=True)
output_cnn = final_pred(X_TEST, y_TEST, metadata_test, algo="cnn", 
                        scaler_model_name="CNN_7folds", plt_save=True)

# Apply threshold-moving
output_lgb = apply_threshold_pred(output_lgb, 0.479)
output_cnn = apply_threshold_pred(output_cnn, 0.492)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}default/lgbm_7folds_removed_wrongly_sure_test_output_thresholded_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_removed_wrongly_sure_test_output_thresholded_{FILENAME}.csv", index=False)
# Out:
# Performing prediction with LGBM_7folds model
# Algorithm = LGBM
# Test examples:
#     Total: 184182
#     Positive: 88247 (47.91% of total)
#
# > Starting pred iteration 1
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/timepoint_0to2_removed_wrongly_sure_merged_subtnorm/models/LGBM_7folds_cv_1_scaler_timepoint_0to2_removed_wrongly_sure_lgbm_merged_subtnorm.pkl
# Loading model:	/binf-isilon/alab/students/stefano/thesis_project/Models/timepoint_0to2_removed_wrongly_sure_merged_subtnorm/models/LGBM_7folds_cv_1_model_timepoint_0to2_removed_wrongly_sure_lgbm_merged_subtnorm.txt
# Report:
# Test F1-score: 0.7445
# Test MCC: 0.496
# Test TNR = 82.28%
# Test TPR = 66.58%
# Test Precision = 0.7756
# Test Recall = 0.6658
#
# > Starting pred iteration 2
# ...

# %%
# Predictions on TP6 without confusing samples old model
output_lgb = final_pred(X_TEST, y_TEST, metadata_test, algo="lgbm", 
                        scaler_model_name="LGBM_7folds", plt_save=True)
output_cnn = final_pred(X_TEST, y_TEST, metadata_test, algo="cnn", 
                        scaler_model_name="CNN_7folds", plt_save=True)

# Apply threshold-moving
output_lgb = apply_threshold_pred(output_lgb, 0.479)
output_cnn = apply_threshold_pred(output_cnn, 0.492)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}default/lgbm_7folds_test_output_thresholded_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_test_output_thresholded_{FILENAME}.csv", index=False)
# Out:
# Performing prediction with LGBM_7folds model
# Algorithm = LGBM
# Test examples:
#     Total: 170636
#     Positive: 79922 (46.84% of total)
#
# > Starting pred iteration 1
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# Loading model:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_1_model_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.txt
# Report:
# Test F1-score: 0.8008
# Test MCC: 0.6098
# Test TNR = 88.17%
# Test TPR = 71.65%
# Test Precision = 0.8422
# Test Recall = 0.7165
#
# > Starting pred iteration 2
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/pos_neg_shift_timepoint_0to2_all_merged_subtnorm/LGBM_7folds_cv_2_scaler_pos_neg_shift_timepoint_0to2_all_merged_subtnorm.pkl
# ...

# %%
# Predictions on TP6 without confusing samples new model
output_lgb = final_pred(X_TEST, y_TEST, metadata_test, algo="lgbm", 
                        scaler_model_name="LGBM_7folds", plt_save=True)
output_cnn = final_pred(X_TEST, y_TEST, metadata_test, algo="cnn", 
                        scaler_model_name="CNN_7folds", plt_save=True)

# Apply threshold-moving
output_lgb = apply_threshold_pred(output_lgb, 0.479)
output_cnn = apply_threshold_pred(output_cnn, 0.492)

# Store prediction
output_lgb.to_csv(f"{OUT_PATH_ML_RESULT}default/lgbm_7folds_removed_wrongly_sure_test_output_thresholded_{FILENAME}.csv", index=False)
output_cnn.to_csv(f"{OUT_PATH_ML_RESULT}default/cnn_7folds_removed_wrongly_sure_test_output_thresholded_{FILENAME}.csv", index=False)
# Out:
# Performing prediction with LGBM_7folds model
# Algorithm = LGBM
# Test examples:
#     Total: 170636
#     Positive: 79922 (46.84% of total)
#
# > Starting pred iteration 1
# Loading scaler:	/binf-isilon/alab/students/stefano/thesis_project/Models/timepoint_0to2_removed_wrongly_sure_merged_subtnorm/models/LGBM_7folds_cv_1_scaler_timepoint_0to2_removed_wrongly_sure_lgbm_merged_subtnorm.pkl
# Loading model:	/binf-isilon/alab/students/stefano/thesis_project/Models/timepoint_0to2_removed_wrongly_sure_merged_subtnorm/models/LGBM_7folds_cv_1_model_timepoint_0to2_removed_wrongly_sure_lgbm_merged_subtnorm.txt
# Report:
# Test F1-score: 0.8041
# Test MCC: 0.6132
# Test TNR = 87.01%
# Test TPR = 73.51%
# Test Precision = 0.8329
# Test Recall = 0.7351
#
# > Starting pred iteration 2
# ...
